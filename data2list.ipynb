# %%
import matplotlib.pyplot as plt
csvfile=open('Drag_Coefficient_vs_Mach.csv','r')
lines=csvfile.readlines()
mach_SV=[]
C_D_SV=[]
for line in lines:
    m,c=line.split(', ')
    m=float(m)
    c=float(c.rstrip('\n'))
    mach_SV.append(m)
    C_D_SV.append(c)

fig=plt.figure(figsize=(10,6))
ax=fig.add_subplot(111)
ax.plot(mach_SV,C_D_SV,'r-')
ax.set_xlabel('Mach Number')
ax.set_ylabel('Drag Coefficient')
ax.set_title('Drag Coefficient vs Mach Number')
plt.show()

print('mach_SV =',mach)
print('\n\n')
print('C_D_SV =',C_D)
# Out:
# mach_SV = [0.008442947521733135, 0.057780710937143986, 0.1092121432797779, 0.18310955350234392, 0.26372491010877974, 0.34434026671521556, 0.4249556233216514, 0.505570979928087, 0.5861863365345228, 0.6533658003732192, 0.7119079045755119, 0.7487606390241681, 0.7863811387738384, 0.8159401028628648, 0.8414682991215696, 0.8683400846570479, 0.8965554594693006, 0.922083655728005, 0.9489554412634837, 0.9758272267989625, 1.0026990123344408, 1.0295707978699196, 1.0564425834053979, 1.0833143689408766, 1.1101861544763554, 1.1370579400118337, 1.1639297255473124, 1.1908015110827912, 1.2163297073414956, 1.2445450821537483, 1.2727604569660005, 1.3117245459924445, 1.3789040098311411, 1.459519366437577, 1.5401347230440128, 1.6140321332665786, 1.6812115971052752, 1.7416731145601019, 1.7954166856310594, 1.8491602567020164, 1.8827499886213648, 1.9230576669245827, 1.9633653452278006, 2.0137499431068226, 2.043980701834236, 2.078914023030358, 2.122676645188138, 2.1649037367438897, 2.199837057940012, 2.23880
# ...

# %%
import matplotlib.pyplot as plt
csvfile=open('US_Standard_Atmo.txt','r')
lines=csvfile.readlines()
alt_USSA=[]
temp_USSA=[]
density_USSA=[]
for line in lines:
    alt,sigma,delta,theta,temp,press,dens,a,visc,k_visc=line.split()
    alt=float(alt)*1000.
    temp=float(temp)-273.
    dens=float(dens)
    alt_USSA.append(alt)
    temp_USSA.append(temp)
    density_USSA.append(dens)
fig=plt.figure(figsize=(10,9))
ax1=fig.add_subplot(211)
ax1.plot(alt_USSA,temp_USSA,'r-')
ax1.set_ylabel('Temperature (deg C)')
ax1.set_title('U.S. Standard Atmospere, 1976')
ax2=fig.add_subplot(212)
ax2.plot(alt_USSA,density_USSA,'b-')
ax2.set_xlabel('Altitude (m)')
ax2.set_ylabel('Density (kg/m^3)')

plt.show()

print('alt_USSA =',alt_USSA)
print('\n\n')
print('temp_USSA =',temp_USSA)
print('\n\n')
print('density_USSA =',density_USSA)
# Out:
# alt_USSA = [-2000.0, 0.0, 2000.0, 4000.0, 6000.0, 8000.0, 10000.0, 12000.0, 14000.0, 16000.0, 18000.0, 20000.0, 22000.0, 24000.0, 26000.0, 28000.0, 30000.0, 32000.0, 34000.0, 36000.0, 38000.0, 40000.0, 42000.0, 44000.0, 46000.0, 48000.0, 50000.0, 52000.0, 54000.0, 56000.0, 58000.0, 60000.0, 62000.0, 64000.0, 66000.0, 68000.0, 70000.0, 72000.0, 74000.0, 76000.0, 78000.0, 80000.0, 82000.0, 84000.0, 86000.0]
#
#
#
# ...
